# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random 2D points
np.random.seed(1)
x = np.random.randn(100)
y = np.random.randn(100)

# Create a larger figure
plt.figure(figsize=(18, 8))  # Adjust the width and height as desired

# Create the scatter plot with somewhat transparent points
plt.scatter(x, y, alpha=0.5)

# Set plot title and labels
plt.title('Scatter Plot of 2D Points')
plt.xlabel('X')
plt.ylabel('Y')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

# %%
xy=pd.concat([pd.DataFrame(pd.read_csv('Densities5by5.csv',header=None)[0].apply(lambda tup:tup.split(' ')[0])).rename(columns={0:'x'}),
 pd.DataFrame(pd.read_csv('Densities5by5.csv',header=None)[0].apply(lambda tup:tup.split(' ')[1])).rename(columns={0:'y'})],axis=1)

# %%
xy['x'].astype(float)
# Out:
# 0      0.000
# 1      0.001
# 2      0.002
# 3      0.003
# 4      0.004
#        ...
# 995    0.995
# 996    0.996
# 997    0.997
# 998    0.998
# 999    0.999
# Name: x, Length: 1000, dtype: float64

# %%
xy['x']
# Out:
# 0          0
# 1      0.001
# 2      0.002
# 3      0.003
# 4      0.004
#        ...
# 995    0.995
# 996    0.996
# 997    0.997
# 998    0.998
# 999    0.999
# Name: x, Length: 1000, dtype: object

# %%
xy.plot(kind='scatter',x='x',y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
x = xy['x'].astype(float)
y = xy['y'].astype(float)
plt.figure(figsize=(18, 8))
plt.scatter(x, y, alpha=0.5)
plt.title('Solution density vs. spatial density')
plt.xlabel('spatial density')
plt.ylabel('solution density')
plt.show()
